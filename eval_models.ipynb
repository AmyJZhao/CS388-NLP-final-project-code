# %% [markdown]
# <a href="https://colab.research.google.com/github/AmyJZhao/CS388-NLP-final-project-code/blob/main/eval_models.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # ELECTRA model performance
# Evaluted on:
#
# *   SQUAD
# *   SQUAD 2.0
# *   SQUAD Adversarial AddSent
# *   SQUAD Adversarial AddOneSent

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd /content/drive/MyDrive/fp-model-eval
# !pip install -r requirements.txt
# Out:
# /content/drive/MyDrive/fp-model-eval
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 5.3 MB 4.7 MB/s
# ...
#      |████████████████████████████████| 441 kB 90.7 MB/s
# ...
#      |████████████████████████████████| 182 kB 87.2 MB/s
# ...
#      |████████████████████████████████| 7.6 MB 84.4 MB/s
# ...
#      |████████████████████████████████| 212 kB 88.6 MB/s
# ...
#      |████████████████████████████████| 95 kB 6.7 MB/s
# ...
#      |████████████████████████████████| 132 kB 98.4 MB/s
# ...
#      |████████████████████████████████| 127 kB 94.0 MB/s
# ...
#      |████████████████████████████████| 131 kB 93.6 MB/s
# ...
#   Attempting uninstall: urllib3
#     Found existing installation: urllib3 1.24.3
#     Uninstalling urllib3-1.24.3:
#       Successfully uninstalled urllib3-1.24.3
#   Attempting uninstall: dill
#     Found existing installation: dill 0.3.6
#     Uninstalling dill-0.3.6:
#       Successfully uninstalled dill-0.3.6
# ...

# %% [markdown]
# ### SQUAD model

# %%
# !python3 run.py --do_eval --task qa --dataset squad --model ../fp-model-train/models/squad/ --output_dir ./eval/squad_model/squad
# Out:
# 2022-12-05 01:45:34.546429: I tensorflow/core/util/util.cc:169] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# ...
# Extracting data files: 100% 2/2 [00:00<00:00, 1521.33it/s]
# Dataset squad downloaded and prepared to /root/.cache/huggingface/datasets/squad/plain_text/1.0.0/d6ec3ceb99ca480ce37cdd35555d6cb2511d223b9150cce08a837ef62ffea453. Subsequent calls will reuse this data.
# 100% 2/2 [00:00<00:00, 311.17it/s]
# Preprocessing data... (this takes a little bit, should only happen once per dataset)
# #0:   0% 0/6 [00:00<?, ?ba/s]
# #0:  17% 1/6 [00:00<00:04,  1.18ba/s]
# #0:  33% 2/6 [00:01<00:03,  1.26ba/s]
# #0:  50% 3/6 [00:02<00:02,  1.28ba/s]
# #0:  67% 4/6 [00:03<00:01,  1.24ba/s]
# #0:  83% 5/6 [00:04<00:00,  1.12ba/s]
# #0:  83% 5/6 [00:04<00:00,  1.06ba/s]
# #1:  83% 5/6 [00:04<00:00,  1.03ba/s]
# ...

# %%
# !python3 run_squad_v2.py --do_eval --task qa --dataset squad_v2 --model ../fp-model-train/models/squad/ --output_dir ./eval/squad_model/squad_v2
# Out:
# 2022-12-05 01:49:54.015390: I tensorflow/core/util/util.cc:169] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# ...
# Extracting data files: 100% 2/2 [00:00<00:00, 1463.73it/s]
# Dataset squad_v2 downloaded and prepared to /root/.cache/huggingface/datasets/squad_v2/squad_v2/2.0.0/09187c73c1b837c95d9a249cd97c2c3f1cebada06efe667b4427714b27639b1d. Subsequent calls will reuse this data.
# 100% 2/2 [00:00<00:00, 629.59it/s]
# Preprocessing data... (this takes a little bit, should only happen once per dataset)
# #0:   0% 0/6 [00:00<?, ?ba/s]
# #0:  17% 1/6 [00:00<00:04,  1.02ba/s]
# #0:  33% 2/6 [00:01<00:03,  1.12ba/s]
# #0:  50% 3/6 [00:02<00:02,  1.15ba/s]
# #1:  50% 3/6 [00:02<00:02,  1.07ba/s]
# #0:  67% 4/6 [00:03<00:01,  1.04ba/s]
# #1:  83% 5/6 [00:05<00:01,  1.07s/ba]
# ...

# %%
# !python3 run.py --do_eval --task qa --dataset squad_adversarial:AddSent --model ../fp-model-train/models/squad/ --output_dir ./eval/squad_model/squad_adv_addsent
# Out:
# 2022-12-05 01:53:04.837183: I tensorflow/core/util/util.cc:169] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# ...
# Extracting data files: 100% 2/2 [00:00<00:00, 1533.57it/s]
# Dataset squad_adversarial downloaded and prepared to /root/.cache/huggingface/datasets/squad_adversarial/AddSent/1.1.0/e9df92c060f50eb529284b303c504bf4359ba37944faebe7a16a91b7d534e946. Subsequent calls will reuse this data.
# 100% 1/1 [00:00<00:00, 644.58it/s]
# Preprocessing data... (this takes a little bit, should only happen once per dataset)
# #0:   0% 0/2 [00:00<?, ?ba/s]
# #0:  50% 1/2 [00:00<00:00,  1.16ba/s]
# #0:  50% 1/2 [00:01<00:01,  1.85s/ba]
# #1:  50% 1/2 [00:01<00:01,  1.88s/ba]
# ...

# %%
# !python3 run.py --do_eval --task qa --dataset squad_adversarial:AddOneSent --model ../fp-model-train/models/squad/ --output_dir ./eval/squad_model/squad_adv_addonesent
# Out:
# 2022-12-05 01:53:42.803038: I tensorflow/core/util/util.cc:169] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# ...
# Extracting data files: 100% 2/2 [00:00<00:00, 1568.26it/s]
# Dataset squad_adversarial downloaded and prepared to /root/.cache/huggingface/datasets/squad_adversarial/AddOneSent/1.1.0/e9df92c060f50eb529284b303c504bf4359ba37944faebe7a16a91b7d534e946. Subsequent calls will reuse this data.
# 100% 1/1 [00:00<00:00, 662.29it/s]
# Preprocessing data... (this takes a little bit, should only happen once per dataset)
# #0:   0% 0/1 [00:00<?, ?ba/s]
# #0:   0% 0/1 [00:00<?, ?ba/s]
# #1:   0% 0/1 [00:00<?, ?ba/s]
# ...

# %% [markdown]
# ### SQUAD 2.0 model

# %%
# !python3 run.py --do_eval --task qa --dataset squad --model ../fp-model-train/models/squad_v2/ --output_dir ./eval/squad_v2_model/squad
# Out:
# 2022-12-05 02:35:23.983983: I tensorflow/core/util/util.cc:169] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# WARNING:datasets.builder:Found cached dataset squad (/root/.cache/huggingface/datasets/squad/plain_text/1.0.0/d6ec3ceb99ca480ce37cdd35555d6cb2511d223b9150cce08a837ef62ffea453)
# 100% 2/2 [00:00<00:00, 473.69it/s]
# Preprocessing data... (this takes a little bit, should only happen once per dataset)
# #0:   0% 0/6 [00:00<?, ?ba/s]
# #0:  17% 1/6 [00:00<00:04,  1.18ba/s]
# #0:  33% 2/6 [00:01<00:03,  1.28ba/s]
# #0:  50% 3/6 [00:02<00:02,  1.28ba/s]
# #0:  67% 4/6 [00:03<00:01,  1.14ba/s]
# #0:  83% 5/6 [00:04<00:00,  1.07ba/s]
# #0:  83% 5/6 [00:04<00:00,  1.07ba/s]
# #1:  83% 5/6 [00:04<00:00,  1.03ba/s]
# ...

# %%
# !python3 run_squad_v2.py --do_eval --task qa --dataset squad_v2 --model ../fp-model-train/models/squad_v2/ --output_dir ./eval/squad_v2_model/squad_v2
# Out:
# 2022-12-05 02:36:46.712661: I tensorflow/core/util/util.cc:169] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# WARNING:datasets.builder:Found cached dataset squad_v2 (/root/.cache/huggingface/datasets/squad_v2/squad_v2/2.0.0/09187c73c1b837c95d9a249cd97c2c3f1cebada06efe667b4427714b27639b1d)
# 100% 2/2 [00:00<00:00, 452.09it/s]
# Preprocessing data... (this takes a little bit, should only happen once per dataset)
# #0:   0% 0/6 [00:00<?, ?ba/s]
# #0:  17% 1/6 [00:00<00:03,  1.25ba/s]
# #0:  33% 2/6 [00:01<00:03,  1.24ba/s]
# #0:  50% 3/6 [00:02<00:02,  1.21ba/s]
# #1:  50% 3/6 [00:02<00:02,  1.13ba/s]
# #0:  67% 4/6 [00:03<00:02,  1.03s/ba]
# #1:  83% 5/6 [00:05<00:01,  1.07s/ba]
# #0:  83% 5/6 [00:05<00:01,  1.10s/ba]
# ...

# %%
# !python3 run.py --do_eval --task qa --dataset squad_adversarial:AddSent --model ../fp-model-train/models/squad_v2/ --output_dir ./eval/squad_v2_model/squad_adv_addsent
# Out:
# 2022-12-05 02:38:35.505182: I tensorflow/core/util/util.cc:169] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# WARNING:datasets.builder:Found cached dataset squad_adversarial (/root/.cache/huggingface/datasets/squad_adversarial/AddSent/1.1.0/e9df92c060f50eb529284b303c504bf4359ba37944faebe7a16a91b7d534e946)
# 100% 1/1 [00:00<00:00, 524.29it/s]
# Preprocessing data... (this takes a little bit, should only happen once per dataset)
# #0:   0% 0/2 [00:00<?, ?ba/s]
# #0:  50% 1/2 [00:00<00:00,  1.17ba/s]
# #0:  50% 1/2 [00:01<00:01,  1.62s/ba]
# #1:  50% 1/2 [00:01<00:01,  1.66s/ba]
# run.py:133: FutureWarning: load_metric is deprecated and will be removed in the next major version of datasets. Use 'evaluate.load' instead, from the new library 🤗 Evaluate: https://huggingface.co/docs/evaluate
# ...

# %%
# !python3 run.py --do_eval --task qa --dataset squad_adversarial:AddOneSent --model ../fp-model-train/models/squad_v2/ --output_dir ./eval/squad_v2_model/squad_adv_addonesent
# Out:
# 2022-12-05 02:39:10.468552: I tensorflow/core/util/util.cc:169] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# WARNING:datasets.builder:Found cached dataset squad_adversarial (/root/.cache/huggingface/datasets/squad_adversarial/AddOneSent/1.1.0/e9df92c060f50eb529284b303c504bf4359ba37944faebe7a16a91b7d534e946)
# 100% 1/1 [00:00<00:00, 539.11it/s]
# Preprocessing data... (this takes a little bit, should only happen once per dataset)
# #0:   0% 0/1 [00:00<?, ?ba/s]
# #0:   0% 0/1 [00:00<?, ?ba/s]
# #1:   0% 0/1 [00:00<?, ?ba/s]
# run.py:133: FutureWarning: load_metric is deprecated and will be removed in the next major version of datasets. Use 'evaluate.load' instead, from the new library 🤗 Evaluate: https://huggingface.co/docs/evaluate
#   metric = datasets.load_metric('squad')
# ...

# %% [markdown]
# ### SQUAD Adversarial AddSent model

# %%
# !python3 run.py --do_eval --task qa --dataset squad --model ../fp-model-train/models/squad_adv/addsent/ --output_dir ./eval/squad_adv_addsent_model/squad
# Out:
# 2022-12-05 02:54:46.945518: I tensorflow/core/util/util.cc:169] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# WARNING:datasets.builder:Found cached dataset squad (/root/.cache/huggingface/datasets/squad/plain_text/1.0.0/d6ec3ceb99ca480ce37cdd35555d6cb2511d223b9150cce08a837ef62ffea453)
# 100% 2/2 [00:00<00:00, 443.26it/s]
# Preprocessing data... (this takes a little bit, should only happen once per dataset)
# #0:   0% 0/6 [00:00<?, ?ba/s]
# #0:  17% 1/6 [00:00<00:04,  1.17ba/s]
# #0:  33% 2/6 [00:01<00:03,  1.26ba/s]
# #0:  50% 3/6 [00:02<00:02,  1.28ba/s]
# #0:  67% 4/6 [00:03<00:01,  1.15ba/s]
# #0:  83% 5/6 [00:04<00:00,  1.08ba/s]
# #0:  83% 5/6 [00:04<00:00,  1.07ba/s]
# #1:  83% 5/6 [00:04<00:00,  1.03ba/s]
# ...

# %%
# !python3 run_squad_v2.py --do_eval --task qa --dataset squad_v2 --model ../fp-model-train/models/squad_adv/addsent/ --output_dir ./eval/squad_adv_addsent_model/squad_v2
# Out:
# 2022-12-05 02:56:10.151410: I tensorflow/core/util/util.cc:169] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# WARNING:datasets.builder:Found cached dataset squad_v2 (/root/.cache/huggingface/datasets/squad_v2/squad_v2/2.0.0/09187c73c1b837c95d9a249cd97c2c3f1cebada06efe667b4427714b27639b1d)
# 100% 2/2 [00:00<00:00, 451.41it/s]
# Preprocessing data... (this takes a little bit, should only happen once per dataset)
# #0:   0% 0/6 [00:00<?, ?ba/s]
# #0:  17% 1/6 [00:00<00:04,  1.24ba/s]
# #0:  33% 2/6 [00:01<00:03,  1.24ba/s]
# #0:  50% 3/6 [00:02<00:02,  1.22ba/s]
# #1:  50% 3/6 [00:02<00:02,  1.13ba/s]
# #0:  67% 4/6 [00:03<00:02,  1.01s/ba]
# #1:  83% 5/6 [00:05<00:01,  1.07s/ba]
# #0:  83% 5/6 [00:05<00:01,  1.09s/ba]
# ...

# %%
# !python3 run.py --do_eval --task qa --dataset squad_adversarial:AddSent --model ../fp-model-train/models/squad_adv/addsent/ --output_dir ./eval/squad_adv_addsent_model/squad_adv_addsent
# Out:
# 2022-12-05 02:57:58.556484: I tensorflow/core/util/util.cc:169] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# WARNING:datasets.builder:Found cached dataset squad_adversarial (/root/.cache/huggingface/datasets/squad_adversarial/AddSent/1.1.0/e9df92c060f50eb529284b303c504bf4359ba37944faebe7a16a91b7d534e946)
# 100% 1/1 [00:00<00:00, 571.43it/s]
# Preprocessing data... (this takes a little bit, should only happen once per dataset)
# #0:   0% 0/2 [00:00<?, ?ba/s]
# #0:  50% 1/2 [00:00<00:00,  1.16ba/s]
# #0:  50% 1/2 [00:01<00:01,  1.64s/ba]
# #1:  50% 1/2 [00:01<00:01,  1.67s/ba]
# run.py:133: FutureWarning: load_metric is deprecated and will be removed in the next major version of datasets. Use 'evaluate.load' instead, from the new library 🤗 Evaluate: https://huggingface.co/docs/evaluate
# ...

# %%
# !python3 run.py --do_eval --task qa --dataset squad_adversarial:AddOneSent --model ../fp-model-train/models/squad_adv/addsent/ --output_dir ./eval/squad_adv_addsent_model/squad_adv_addonesent
# Out:
# 2022-12-05 02:58:33.669940: I tensorflow/core/util/util.cc:169] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# WARNING:datasets.builder:Found cached dataset squad_adversarial (/root/.cache/huggingface/datasets/squad_adversarial/AddOneSent/1.1.0/e9df92c060f50eb529284b303c504bf4359ba37944faebe7a16a91b7d534e946)
# 100% 1/1 [00:00<00:00, 491.42it/s]
# Preprocessing data... (this takes a little bit, should only happen once per dataset)
# #0:   0% 0/1 [00:00<?, ?ba/s]
# #0:   0% 0/1 [00:00<?, ?ba/s]
# #1:   0% 0/1 [00:00<?, ?ba/s]
# run.py:133: FutureWarning: load_metric is deprecated and will be removed in the next major version of datasets. Use 'evaluate.load' instead, from the new library 🤗 Evaluate: https://huggingface.co/docs/evaluate
#   metric = datasets.load_metric('squad')
# ...

# %% [markdown]
# ### SQUAD Adversarial AddOneSent model

# %%
# !python3 run.py --do_eval --task qa --dataset squad --model ../fp-model-train/models/squad_adv/addonesent/ --output_dir ./eval/squad_adv_addonesent_model/squad
# Out:
# 2022-12-05 02:58:56.473613: I tensorflow/core/util/util.cc:169] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# WARNING:datasets.builder:Found cached dataset squad (/root/.cache/huggingface/datasets/squad/plain_text/1.0.0/d6ec3ceb99ca480ce37cdd35555d6cb2511d223b9150cce08a837ef62ffea453)
# 100% 2/2 [00:00<00:00, 497.34it/s]
# Preprocessing data... (this takes a little bit, should only happen once per dataset)
# #0:   0% 0/6 [00:00<?, ?ba/s]
# #0:  17% 1/6 [00:00<00:04,  1.16ba/s]
# #0:  33% 2/6 [00:01<00:03,  1.26ba/s]
# #0:  50% 3/6 [00:02<00:02,  1.27ba/s]
# #0:  67% 4/6 [00:03<00:01,  1.14ba/s]
# #0:  83% 5/6 [00:04<00:00,  1.07ba/s]
# #0:  83% 5/6 [00:04<00:00,  1.06ba/s]
# #1:  83% 5/6 [00:04<00:00,  1.03ba/s]
# ...

# %%
# !python3 run_squad_v2.py --do_eval --task qa --dataset squad_v2 --model ../fp-model-train/models/squad_adv/addonesent/ --output_dir ./eval/squad_adv_addonesent_model/squad_v2
# Out:
# 2022-12-05 03:00:18.640688: I tensorflow/core/util/util.cc:169] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# WARNING:datasets.builder:Found cached dataset squad_v2 (/root/.cache/huggingface/datasets/squad_v2/squad_v2/2.0.0/09187c73c1b837c95d9a249cd97c2c3f1cebada06efe667b4427714b27639b1d)
# 100% 2/2 [00:00<00:00, 439.06it/s]
# Preprocessing data... (this takes a little bit, should only happen once per dataset)
# #0:   0% 0/6 [00:00<?, ?ba/s]
# #0:  17% 1/6 [00:00<00:03,  1.25ba/s]
# #0:  33% 2/6 [00:01<00:03,  1.24ba/s]
# #0:  50% 3/6 [00:02<00:02,  1.23ba/s]
# #1:  50% 3/6 [00:02<00:02,  1.13ba/s]
# #0:  67% 4/6 [00:03<00:02,  1.01s/ba]
# #1:  83% 5/6 [00:05<00:01,  1.06s/ba]
# #0:  83% 5/6 [00:05<00:01,  1.08s/ba]
# ...

# %%
# !python3 run.py --do_eval --task qa --dataset squad_adversarial:AddSent --model ../fp-model-train/models/squad_adv/addonesent/ --output_dir ./eval/squad_adv_addonesent_model/squad_adv_addsent
# Out:
# 2022-12-05 03:02:07.692829: I tensorflow/core/util/util.cc:169] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# WARNING:datasets.builder:Found cached dataset squad_adversarial (/root/.cache/huggingface/datasets/squad_adversarial/AddSent/1.1.0/e9df92c060f50eb529284b303c504bf4359ba37944faebe7a16a91b7d534e946)
# 100% 1/1 [00:00<00:00, 645.97it/s]
# Preprocessing data... (this takes a little bit, should only happen once per dataset)
# #0:   0% 0/2 [00:00<?, ?ba/s]
# #0:  50% 1/2 [00:00<00:00,  1.16ba/s]
# #0:  50% 1/2 [00:01<00:01,  1.63s/ba]
# #1:  50% 1/2 [00:01<00:01,  1.66s/ba]
# run.py:133: FutureWarning: load_metric is deprecated and will be removed in the next major version of datasets. Use 'evaluate.load' instead, from the new library 🤗 Evaluate: https://huggingface.co/docs/evaluate
# ...

# %%
# !python3 run.py --do_eval --task qa --dataset squad_adversarial:AddOneSent --model ../fp-model-train/models/squad_adv/addonesent/ --output_dir ./eval/squad_adv_addonesent_model/squad_adv_addonesent
# Out:
# 2022-12-05 03:02:42.787880: I tensorflow/core/util/util.cc:169] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# WARNING:datasets.builder:Found cached dataset squad_adversarial (/root/.cache/huggingface/datasets/squad_adversarial/AddOneSent/1.1.0/e9df92c060f50eb529284b303c504bf4359ba37944faebe7a16a91b7d534e946)
# 100% 1/1 [00:00<00:00, 544.43it/s]
# Preprocessing data... (this takes a little bit, should only happen once per dataset)
# #0:   0% 0/1 [00:00<?, ?ba/s]
# #0:   0% 0/1 [00:00<?, ?ba/s]
# #1:   0% 0/1 [00:00<?, ?ba/s]
# run.py:133: FutureWarning: load_metric is deprecated and will be removed in the next major version of datasets. Use 'evaluate.load' instead, from the new library 🤗 Evaluate: https://huggingface.co/docs/evaluate
#   metric = datasets.load_metric('squad')
# ...

# %% [markdown]
# ## Results
#
# Exact match
#
# |                            | SQUAD train | SQUAD 2.0 train | SQUAD Adv. AddSent train | SQUAD Adv. AddOneSent train |
# |----------------------------|-------------|-----------------|--------------------------|-----------------------------|
# | **SQUAD eval**                 | 78.42       | 77.89           | 38.54                    | 35.30                       |
# | **SQUAD 2.0 eval**             | 39.16       | 70.07           | 19.54                    | 17.89                       |
# | **SQUAD Adv. AddSent eval**    | 55.42       | 59.80           | 94.10                    | 65.89                       |
# | **SQUAD Adv. AddOneSent eval** | 64.18       | 66.98           | 91.49                    | 66.31                       |
#
# F1 Score
#
# |                            | SQUAD train | SQUAD 2.0 train | SQUAD Adv. AddSent train | SQUAD Adv. AddOneSent train |
# |----------------------------|-------------|-----------------|--------------------------|-----------------------------|
# | **SQUAD eval**                 | 86.23       | 85.93           | 47.89                    | 46.02                       |
# | **SQUAD 2.0 eval**             | 43.19       | 73.33           | 24.50                    | 23.40                       |
# | **SQUAD Adv. AddSent eval**    | 62.29       | 67.34           | 96.13                    | 75.07                       |
# | **SQUAD Adv. AddOneSent eval** | 71.27       | 74.60           | 94.10                    | 75.38                       |
